# %% [markdown]
# # Module 1

# %%
#Q1 Load the Sample 2 CSV File

import pandas as pd
sp2 = pd.read_csv(r"C:\Users\ram singh\Desktop\Term2_Python_Project\sample2_group24_035043_035037.csv", low_memory=False)
sp2
# Out:
#        Unnamed: 0  Store        Date  Temperature  Fuel_Price    MarkDown1  \
# 0               0      1  05/02/2010    42.310000    2.572000  7700.424406
# 1               1      1  12/02/2010    38.510000    2.548000  7700.424406
# 2               2      1  19/02/2010    39.930000    2.514000  7700.424406
# 3               3      1  26/02/2010    46.630000    2.561000  7700.424406
# 4               4      1  05/03/2010    46.500000    2.625000  7700.424406
# ...           ...    ...         ...          ...         ...          ...
# 74717       74717     43  26/10/2012    64.716429    3.361586  7700.424406
# 74718       74718     43  06/05/2011    64.716429    3.361586  7700.424406
# 74719       74719     43  18/11/2011    64.716429    3.361586  7700.424406
# 74720       74720     43  06/01/2012    64.716429    3.361586  7700.424406
# 74721       74721     43  15/06/2012    64.716429    3.361586  7700.424406
#
# ...

# %%
# Q2 Generate a Report on Descriptive Statistics of Categorical Data in the Sample

categorical_columns = sp2.select_dtypes(include=["object"])
categorical_columns.describe()
# Out:
#               Date IsHoliday Type
# count        74714     74722    8
# unique         182         3    3
# top     17/02/2012     False    A
# freq           535     69461    3

# %%
# Q3 Generate a Report on Descriptive Statistics of Non-Categorical Data in the Sample 

non_categorical_columns = sp2.select_dtypes(exclude=["object"])
non_categorical_columns.describe()
# Out:
#          Unnamed: 0         Store   Temperature    Fuel_Price     MarkDown1  \
# count  74722.000000  74722.000000  74722.000000  74722.000000  74722.000000
# mean   37360.500000     26.801370     64.716429      3.361586   7700.424406
# std    21570.527744     13.717357      2.289263      0.059084    981.487780
# min        0.000000      1.000000     18.300000      2.514000      1.500000
# 25%    18680.250000     12.000000     64.716429      3.361586   7700.424406
# 50%    37360.500000     31.000000     64.716429      3.361586   7700.424406
# 75%    56040.750000     37.000000     64.716429      3.361586   7700.424406
# max    74721.000000     43.000000    101.950000      4.468000  88750.340000
#
#           MarkDown2      MarkDown3     MarkDown4      MarkDown5           CPI  \
# count  74722.000000   74722.000000  74722.000000   74722.000000  74722.000000
# mean    3054.413755    1500.476408   3837.584313    5385.720444    194.269953
# ...

# %%
# Q4 Generate a Report on Feature-wise Outliers in the Sample

import seaborn as sns
import matplotlib.pyplot as plt

# setting the dimensions of the plot
fig, ax = plt.subplots(figsize=(24, 8))
sns.boxplot(sp2, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Module 2

# %%
# Generate a Comprehensive Report on the Insights Drawn from the Sample about Store Performance (and/or any other Insight)

import pandas as pd
import matplotlib.pyplot as plt

sp2.describe()
# Out:
#          Unnamed: 0         Store   Temperature    Fuel_Price     MarkDown1  \
# count  74722.000000  74722.000000  74722.000000  74722.000000  74722.000000
# mean   37360.500000     26.801370     64.716429      3.361586   7700.424406
# std    21570.527744     13.717357      2.289263      0.059084    981.487780
# min        0.000000      1.000000     18.300000      2.514000      1.500000
# 25%    18680.250000     12.000000     64.716429      3.361586   7700.424406
# 50%    37360.500000     31.000000     64.716429      3.361586   7700.424406
# 75%    56040.750000     37.000000     64.716429      3.361586   7700.424406
# max    74721.000000     43.000000    101.950000      4.468000  88750.340000
#
#           MarkDown2      MarkDown3     MarkDown4      MarkDown5           CPI  \
# count  74722.000000   74722.000000  74722.000000   74722.000000  74722.000000
# mean    3054.413755    1500.476408   3837.584313    5385.720444    194.269953
# ...

# %%
import seaborn as sns 

g = sns.catplot(data=sp2, x='Store', y='Weekly_Sales', color ='green')
g.fig.set_figwidth(15)
g.fig.set_figheight(8)

# %%
# Total Weekly_Sales of Store

Weekly_Sales = sp2.groupby('Store')['Weekly_Sales'].sum()
Weekly_Sales
# Out:
# Store
# 1     2.253282e+08
# 12    1.472127e+08
# 25    1.039866e+08
# 31    2.025393e+08
# 35    1.344461e+08
# 37    7.712817e+07
# 39    2.103710e+08
# 43    9.349087e+07
# Name: Weekly_Sales, dtype: float64

# %%
Weekly_Sales.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Store'>

# %%
# Total Dept of Store

Dept = sp2.groupby('Store')['Dept'].sum()
Dept
# Out:
# Store
# 1     462911.932103
# 12    429961.932103
# 25    435324.932103
# 31    459999.932103
# 35    422672.932103
# 37    346072.932103
# 39    450005.932103
# 43    326112.932103
# Name: Dept, dtype: float64

# %%
Dept.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Store'>

# %%
# calculate the correlation between different columns in the data, which can help to identify relationships between variables.

sp2.corr()
# Out:
#                        Unnamed: 0     Store   Temperature    Fuel_Price  \
# Unnamed: 0           1.000000e+00  0.903458  2.497001e-04 -1.869249e-04
# Store                9.034584e-01  1.000000  2.851472e-04 -1.556626e-02
# Temperature          2.497001e-04  0.000285  1.000000e+00  6.760739e-02
# Fuel_Price          -1.869249e-04 -0.015566  6.760739e-02  1.000000e+00
# MarkDown1           -3.600570e-04 -0.014428 -5.693030e-02  6.917502e-02
# MarkDown2           -1.206168e-04 -0.004686 -2.138261e-01 -7.073938e-02
# MarkDown3           -6.871514e-05 -0.002719 -5.906793e-02 -2.936102e-02
# MarkDown4           -5.259963e-05 -0.002936  6.550458e-03  1.303518e-02
# MarkDown5            1.623842e-04  0.006883  5.653771e-02 -5.754412e-02
# CPI                  6.747798e-04  0.024889  7.225327e-02 -1.948392e-01
# Unemployment        -3.460879e-04 -0.021912  1.114677e-01  3.056567e-02
# Size                -4.155904e-07 -0.003041 -2.667129e-19  1.845374e-19
# ...
